# %%
import pandas as pd
import plotly.express as px

# %%
medals = pd.read_csv('complete_country_medals_by_year.csv')  
medals.head()
# Out:
#          Country Country Code  Gold  Silver  Bronze  Total  Year Host_City  \
# 0  United States          USA    36      26      28     90  1964     Tokyo
# 1   Soviet Union          URS    30      31      35     96  1964     Tokyo
# 2          Japan          JPN    16       5       8     29  1964     Tokyo
# 3        Germany          GER    10      22      18     50  1964     Tokyo
# 4          Italy          ITA    10      10       7     27  1964     Tokyo
#
#   Host_Country
# 0          JPN
# 1          JPN
# 2          JPN
# 3          JPN
# 4          JPN

# %%
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')
df4 = pd.read_csv('df4.csv')

# %%
fig = px.bar(medals, x="Country", y="Total", color="Country",
  animation_frame="Year", animation_group="Country", range_y=[0,140])
fig.show()
# Out:
# <div>                            <div id="1fde5961-e06b-47e0-a25d-e7238b5c87a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fde5961-e06b-47e0-a25d-e7238b5c87a7")) {                    Plotly.newPlot(                        "1fde5961-e06b-47e0-a25d-e7238b5c87a7",                        [{"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=1964<br>Total=%{y}<extra></extra>", "ids": ["United States"], "legendgroup": "United States", "marker": {"color": "#636efa"}, "name": "United States", "offsetgroup": "United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [90], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=1964<br>T
# ...

# %%
distance = pd.read_csv('Country_Capitals_Distance.csv')  
distance.head()
# Out:
#           Country           Capital  GDP (Billions) Latitude Longitude  \
# 0     Afghanistan             Kabul           19.29   34.28N    69.11E
# 1         Albania            Tirane           15.29   41.18N    19.49E
# 2         Algeria           Algiers          171.00   36.42N    03.08E
# 3  American Samoa         Pago Pago             NaN   14.16S   170.43W
# 4         Andorra  Andorra la Vella            3.22   42.31N    01.32E
#
#    Latitude.1  Longitude.1 Latitude Hemisphere Longitude Hemisphere  \
# 0       34.28        69.11               North                 East
# 1       41.18        19.49               North                 East
# 2       36.42         3.08               North                 East
# 3      -14.16      -170.40               South                 West
# 4       42.31         1.32               North                 East
#
#    Distance From Tokyo 1964  ...  Distance From Los Angeles 1984  \
# ...

# %%
import plotly.express as px
#df = px.data.gapminder()
px.scatter(df2, x="Population", y="Total", animation_frame="Year", animation_group="Country",
           size="Life Expectancy at Birth", color="Country", hover_name="Country",
           log_x=False, size_max=55, range_x=[1000,1000000000], range_y=[0,150])
# Out:
# <div>                            <div id="5f051e4d-6e8b-466b-9e97-2f53362ef52d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f051e4d-6e8b-466b-9e97-2f53362ef52d")) {                    Plotly.newPlot(                        "5f051e4d-6e8b-466b-9e97-2f53362ef52d",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Sweden<br>Year=1964<br>Population=%{x}<br>Total=%{y}<br>Life Expectancy at Birth=%{marker.size}<extra></extra>", "hovertext": ["Sweden"], "ids": ["Sweden"], "legendgroup": "Sweden", "marker": {"color": "#636efa", "size": [73.8], "sizemode": "area", "sizeref": 0.027669421487603308, "symbol": "circle"}, "mode": "markers", "name": "Sweden", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7661351.
# ...

# %%
px.scatter(df3, x="Population", y="Total", animation_frame="Year", animation_group="Country",
           size="Life Expectancy at Birth", color="Country", hover_name="Country",
           log_x=False, size_max=55, range_x=[1000,1000000000], range_y=[0,150])
# Out:
# <div>                            <div id="ca02c20b-eb1c-43a6-bd6a-32167fc821a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca02c20b-eb1c-43a6-bd6a-32167fc821a1")) {                    Plotly.newPlot(                        "ca02c20b-eb1c-43a6-bd6a-32167fc821a1",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Germany<br>Year=1972<br>Population=%{x}<br>Total=%{y}<br>Life Expectancy at Birth=%{marker.size}<extra></extra>", "hovertext": ["Germany", "Germany"], "ids": ["Germany", "Germany"], "legendgroup": "Germany", "marker": {"color": "#636efa", "size": [71.0, 71.0], "sizemode": "area", "sizeref": 0.027669421487603308, "symbol": "circle"}, "mode": "markers", "name": "Germany", "orientation": "v", "showlegend": true, 
# ...

# %%
px.scatter(df3, x="Population", y="Total", animation_frame="Year", animation_group="Country",
           size="Gold", color="Country", hover_name="Country",
           log_x=False, size_max=55, range_x=[1000,100000000], range_y=[0,150])
# Out:
# <div>                            <div id="f7e5de59-7a77-4c9d-a5cc-793597032b41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7e5de59-7a77-4c9d-a5cc-793597032b41")) {                    Plotly.newPlot(                        "f7e5de59-7a77-4c9d-a5cc-793597032b41",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Germany<br>Year=1972<br>Population=%{x}<br>Total=%{y}<br>Gold=%{marker.size}<extra></extra>", "hovertext": ["Germany", "Germany"], "ids": ["Germany", "Germany"], "legendgroup": "Germany", "marker": {"color": "#636efa", "size": [20, 13], "sizemode": "area", "sizeref": 0.015537190082644628, "symbol": "circle"}, "mode": "markers", "name": "Germany", "orientation": "v", "showlegend": true, "type": "scatter", "x": 
# ...

# %%
px.scatter(df4, x="Population", y="Total", animation_frame="Year", animation_group="Country",
            color="Country", hover_name="Country", size = 
           log_x=False, size_max=55, range_x=[1000,100000000], range_y=[0,150])
# Out:
#   File "<ipython-input-16-097e3efa12e8>", line 3
#     log_x=False, size_max=55, range_x=[1000,100000000], range_y=[0,150])
#          ^
# SyntaxError: invalid syntax

# %%
fig = px.bar(df3, x="Year", y="Total", color="Country", title="Long-Form Input")
fig.show()
# Out:
# <div>                            <div id="c221ca48-a5de-43c2-bcc4-cffaa8524ae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c221ca48-a5de-43c2-bcc4-cffaa8524ae3")) {                    Plotly.newPlot(                        "c221ca48-a5de-43c2-bcc4-cffaa8524ae3",                        [{"alignmentgroup": "True", "hovertemplate": "Country=Germany<br>Year=%{x}<br>Total=%{y}<extra></extra>", "legendgroup": "Germany", "marker": {"color": "#636efa"}, "name": "Germany", "offsetgroup": "Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1972, 1972, 1976, 1976, 1980, 1984, 1988, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016], "xaxis": "x", "y": [66, 40, 39, 90, 126, 59, 40, 102, 82, 65, 56, 49, 41, 44, 42], 
# ...

# %%
fig = px.bar(df3, x="Latitude Hemisphere", y="Total", color="Country", title="Long-Form Input", 
             animation_frame="Year")
fig.show()
# Out:
# <div>                            <div id="07f5215b-24d2-46f0-9708-3f351fdb9ae2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f5215b-24d2-46f0-9708-3f351fdb9ae2")) {                    Plotly.newPlot(                        "07f5215b-24d2-46f0-9708-3f351fdb9ae2",                        [{"alignmentgroup": "True", "hovertemplate": "Country=Germany<br>Year=1972<br>Latitude Hemisphere=%{x}<br>Total=%{y}<extra></extra>", "legendgroup": "Germany", "marker": {"color": "#636efa"}, "name": "Germany", "offsetgroup": "Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["North", "North"], "xaxis": "x", "y": [66, 40], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Norway<br>Year=1972<br>Latitud
# ...

# %%
#df = px.data.iris()
fig = px.scatter_3d(df3, x='GDP (Billions)', y='Total', z='Population',
              color='Country', animation_frame="Year")
fig.show()
# Out:
# <div>                            <div id="4432e459-9706-489a-84f3-432c9be6c7b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4432e459-9706-489a-84f3-432c9be6c7b2")) {                    Plotly.newPlot(                        "4432e459-9706-489a-84f3-432c9be6c7b2",                        [{"hovertemplate": "Country=Germany<br>Year=1972<br>GDP (Billions)=%{x}<br>Total=%{y}<br>Population=%{z}<extra></extra>", "legendgroup": "Germany", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Germany", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [3861.0, 3861.0], "y": [66, 40], "z": [78688450.0, 78688450.0]}, {"hovertemplate": "Country=Norway<br>Year=1972<br>GDP (Billions)=%{x}<br>Total=%{y}<br>Population=%{z
# ...

# %%
fig = px.bar(df3, x="Country", y="Total", color="Country",
  animation_frame="Year", animation_group="Country", range_y=[0,75])
fig.show()
# Out:
# <div>                            <div id="35a70d9e-5a9d-4b72-a5eb-956a57828618" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a70d9e-5a9d-4b72-a5eb-956a57828618")) {                    Plotly.newPlot(                        "35a70d9e-5a9d-4b72-a5eb-956a57828618",                        [{"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=1972<br>Total=%{y}<extra></extra>", "ids": ["Germany", "Germany"], "legendgroup": "Germany", "marker": {"color": "#636efa"}, "name": "Germany", "offsetgroup": "Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany", "Germany"], "xaxis": "x", "y": [66, 40], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=1972<br>Total
# ...

# %%
df4.head()
# Out:
#    Unnamed: 0    Country  Total  Year  Life Expectancy at Birth  Population
# 0           5     Sweden      8  1964                 73.800000   7661351.0
# 1          23  Australia     18  1964                 70.700000  11121600.0
# 2          28     France     15  1964                 71.400000  48310410.0
# 3          31     Canada      4  1964                 65.312903  19719595.0
# 4          42     France     15  1968                 71.500000  49915403.0

# %%
df3.head()
# Out:
#    Unnamed: 0  Country  Gold  Silver  Bronze  Total  Year  \
# 0          86  Germany    20      23      23     66  1972
# 1          88   Norway     2       1       1      4  1972
# 2          89   Turkey     0       1       0      1  1972
# 3          94  Denmark     1       0       0      1  1972
# 4          96   France     2       4       7     13  1972
#
#    Life Expectancy at Birth  Population  GDP (Billions)  ...  \
# 0                      71.0  78688450.0          3861.0  ...
# 1                      74.6   3933001.0           406.0  ...
# 2                      55.0  37133000.0           761.0  ...
# 3                      73.4   4991596.0           350.0  ...
# 4                      72.4  51700913.0          2716.0  ...
#
#   Distance From Los Angeles 1984 Distance From Seoul 1988  \
# 0                    7288.952903              6269.358107
# 1                    7243.423025              6519.505523
# 2                    8241.393981              5132.585459
# ...
