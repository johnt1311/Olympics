# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import numpy as np

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=True)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\huang\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
# go to website to scrape
url = "https://www.olympedia.org/editions"
browser.visit(url)

# parse HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# read html with pandas (bs4 and parser working on backend)
test_df = pd.read_html(url) # returs list of all tables on the page

# %%
test_df
# Out:
# [         #  Year               City  Country        Opened        Closed  \
#  0        I  1896             Athina      NaN       6 April      15 April
#  1       II  1900              Paris      NaN           NaN           NaN
#  2      III  1904          St. Louis      NaN        14 May           NaN
#  3       IV  1908             London      NaN       13 July           NaN
#  4        V  1912          Stockholm      NaN        6 July       27 July
#  5       VI  1916             Berlin      NaN           NaN           NaN
#  6      VII  1920          Antwerpen      NaN     14 August     30 August
#  7     VIII  1924              Paris      NaN        5 July       27 July
#  8       IX  1928          Amsterdam      NaN       28 July     12 August
#  9        X  1932        Los Angeles      NaN       30 July     14 August
#  10      XI  1936             Berlin      NaN      1 August     16 August
#  11     XII  1940           Helsinki      NaN           NaN           NaN
#  12    XIII  1944             London      NaN           NaN           NaN
#  13     XIV  1948             London      NaN       29 July     14 August
#  14      XV  1952           Helsinki      NaN       19 July      3 August
#  15     XVI  1956          Melbourne      NaN   22 November    8 December
#  16    XVII  1960               Roma      NaN     25 August  11 September
#  17   XVIII  1964              Tokyo      NaN    10 October    24 October
#  18     XIX  1968  Ciudad de MÃ©xico      NaN    12 October    27 October
#  19      XX  1972           MÃ¼nchen      NaN     26 August  11 September
#  20     XXI  1976          MontrÃ©al      NaN       17 July      1 August
#  21    XXII  1980             Moskva      NaN       19 July      3 August
#  22   XXIII  1984        Los Angeles      NaN       28 July     12 August
#  23    XXIV  1988              Seoul      NaN  17 September     2 October
#  24     XXV  1992          Barcelona      NaN       25 July      9 August
#  25    XXVI  1996            Atlanta      NaN       19 July      4 August
#  26   XXVII  2000             Sydney      NaN  15 September     1 October
#  27  XXVIII  2004             Athina      NaN     13 August     29 August
#  28    XXIX  2008            Beijing      NaN      8 August     24 August
#  29     XXX  2012             London      NaN       27 July     12 August
#  30    XXXI  2016     Rio de Janeiro      NaN      5 August     21 August
#  31   XXXII  2020              Tokyo      NaN       23 July      8 August
#  32  XXXIII  2024              Paris      NaN           NaN           NaN
#  33   XXXIV  2028        Los Angeles      NaN           NaN           NaN
#
#                     Competition           Unnamed: 7
#  0               6 â 13 April                  NaN
#  1        14 May â 28 October                  NaN
#  2       1 July â 23 November                  NaN
#  3      27 April â 31 October                  NaN
#  4            5 May â 27 July                  NaN
#  5                          â  Not held due to war
#  6    23 April â 12 September                  NaN
#  7            4 May â 27 July                  NaN
#  8         17 May â 12 August                  NaN
#  9        30 July â 14 August                  NaN
#  10             2 â 16 August                  NaN
#  11                         â  Not held due to war
#  12                         â  Not held due to war
#  13       26 July â 14 August                  NaN
#  14        14 July â 3 August                  NaN
#  15  22 November â 8 December                  NaN
#  16  25 August â 11 September                  NaN
#  17           11 â 24 October                  NaN
#  18           12 â 27 October                  NaN
#  19  26 August â 11 September                  NaN
#  26                        â                  NaN  ,
#      #  Year       City  Country   Opened   Closed     Competition  Unnamed: 7
#  0 NaN  1956  Stockholm      NaN  10 June  17 June  11 â 17 June         NaN,
#      #  Year    City  Country    Opened Closed         Competition  Unnamed: 7
#  0 NaN  1906  Athina      NaN  22 April  2 May  22 April â 2 May         NaN,
#       #  Year          City  Country     Opened      Closed       Competition  \
#  0    I  2010     Singapore      NaN  14 August   26 August  12 â 26 August
#  1   II  2014       Nanjing      NaN  16 August   28 August  14 â 28 August
#  2  III  2018  Buenos Aires      NaN  6 October  18 October  6 â 18 October
#  3   IV  2026         Dakar      NaN        NaN         NaN               â
#
#     Unnamed: 7
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN  ,
#       #  Year         City  Country       Opened       Closed  \
#  0    I  2012    Innsbruck      NaN   13 January   22 January
#  1   II  2016  Lillehammer      NaN  12 February  21 February
#  2  III  2020     Lausanne      NaN    9 January   22 January
#  3   IV  2024      Gangwon      NaN          NaN          NaN
#
#            Competition  Unnamed: 7
#  0   13 â 22 January         NaN
#  1  12 â 21 February         NaN
#  2   10 â 22 January         NaN
#  3                 â         NaN  ,
#     #  Year    City  Country  Opened  Closed              Competition  \
#  0  1  1859  Athina      NaN     NaN     NaN              15 November
#  1  2  1870  Athina      NaN     NaN     NaN              15 November
#  2  3  1875  Athina      NaN     NaN     NaN            11 â 18 May
#  3  4  1889  Athina      NaN     NaN     NaN  1 December â 30 April
#
#     Unnamed: 7
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN  ,
#           #     Year     City  Country  Opened  Closed Competition  Unnamed: 7
#  0      1.0  776 BCE  Olympia      NaN     NaN     NaN         â         NaN
#  1      2.0  772 BCE  Olympia      NaN     NaN     NaN         â         NaN
#  2      3.0  768 BCE  Olympia      NaN     NaN     NaN         â         NaN
#  3      4.0  764 BCE  Olympia      NaN     NaN     NaN         â         NaN
#  4      5.0  760 BCE  Olympia      NaN     NaN     NaN         â         NaN
#  ..     ...      ...      ...      ...     ...     ...         ...         ...
#  289  289.0   377 CE  Olympia      NaN     NaN     NaN         â         NaN
#  290  290.0   381 CE  Olympia      NaN     NaN     NaN         â         NaN
#  291  291.0   385 CE  Olympia      NaN     NaN     NaN         â         NaN
#  292  292.0   389 CE  Olympia      NaN     NaN     NaN         â         NaN
#  293  293.0   393 CE  Olympia      NaN     NaN     NaN         â         NaN
#
#  [294 rows x 8 columns]]

# %%
print(f'Total tables: {len(test_df)}')
# Out:
# Total tables: 8

# %%
# NOTE: code below could also be used to pull Winter from the winter table 
# look for tables with Tokyo
table_tokyo = pd.read_html(url, match="Tokyo", converters={"City":str})
# len(table_tokyo) # returns 1 so that is the table that we want

# %%
# read table as DF
sum_olympic_org = table_tokyo[0]
sum_olympic_org.head()

# NOTE: country coming in as NaN because it is a picture of a flag. Scrape country codes from the img tags.
# Out:
#      #  Year       City  Country   Opened    Closed              Competition  \
# 0    I  1896     Athina      NaN  6 April  15 April           6 â 13 April
# 1   II  1900      Paris      NaN      NaN       NaN    14 May â 28 October
# 2  III  1904  St. Louis      NaN   14 May       NaN   1 July â 23 November
# 3   IV  1908     London      NaN  13 July       NaN  27 April â 31 October
# 4    V  1912  Stockholm      NaN   6 July   27 July        5 May â 27 July
#
#   Unnamed: 7
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# trying to get the country codes
# get the image tag from the correct column in the first table
# set table reference
table_to_scrape = html_soup.find_all('table')[0]

# for td in html_soup.find_all('td'):
#     if td.img:
#         print(td.img['src'])

# get table rows
table_body = table_to_scrape.find_all('tr')

# %%
# get number of rows in the table
body_rows = table_body[0:]
# len(body_rows)

# %%
body_rows
# Out:
# [<tr>
#  <th>#</th>
#  <th>Year</th>
#  <th>City</th>
#  <th>Country</th>
#  <th>Opened</th>
#  <th>Closed</th>
#  <th>Competition</th>
#  <th></th>
#  </tr>,
#  <tr>
#  <td><a href="/editions/1">I</a></td>
#  <td><a href="/editions/1">1896</a></td>
#  <td><a href="/editions/1">Athina</a></td>
#  <td><img src="/images/flags/GRE.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 6 April</td>
#  <td>15 April</td>
#  <td>6 – 13 April</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/2">II</a></td>
#  <td><a href="/editions/2">1900</a></td>
#  <td><a href="/editions/2">Paris</a></td>
#  <td><img src="/images/flags/FRA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td></td>
#  <td></td>
#  <td>14 May – 28 October</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/3">III</a></td>
#  <td><a href="/editions/3">1904</a></td>
#  <td><a href="/editions/3">St. Louis</a></td>
#  <td><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>14 May</td>
#  <td></td>
#  <td> 1 July – 23 November</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/5">IV</a></td>
#  <td><a href="/editions/5">1908</a></td>
#  <td><a href="/editions/5">London</a></td>
#  <td><img src="/images/flags/GBR.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>13 July</td>
#  <td></td>
#  <td>27 April – 31 October</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/6">V</a></td>
#  <td><a href="/editions/6">1912</a></td>
#  <td><a href="/editions/6">Stockholm</a></td>
#  <td><img src="/images/flags/SWE.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 6 July</td>
#  <td>27 July</td>
#  <td> 5 May – 27 July</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/50">VI</a></td>
#  <td><a href="/editions/50">1916</a></td>
#  <td><a href="/editions/50">Berlin</a></td>
#  <td><img src="/images/flags/GER.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td></td>
#  <td></td>
#  <td>—</td>
#  <td>
#  Not held due to war
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/7">VII</a></td>
#  <td><a href="/editions/7">1920</a></td>
#  <td><a href="/editions/7">Antwerpen</a></td>
#  <td><img src="/images/flags/BEL.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>14 August</td>
#  <td>30 August</td>
#  <td>23 April – 12 September</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/8">VIII</a></td>
#  <td><a href="/editions/8">1924</a></td>
#  <td><a href="/editions/8">Paris</a></td>
#  <td><img src="/images/flags/FRA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 5 July</td>
#  <td>27 July</td>
#  <td> 4 May – 27 July</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/9">IX</a></td>
#  <td><a href="/editions/9">1928</a></td>
#  <td><a href="/editions/9">Amsterdam</a></td>
#  <td><img src="/images/flags/NED.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>28 July</td>
#  <td>12 August</td>
#  <td>17 May – 12 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/10">X</a></td>
#  <td><a href="/editions/10">1932</a></td>
#  <td><a href="/editions/10">Los Angeles</a></td>
#  <td><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>30 July</td>
#  <td>14 August</td>
#  <td>30 July – 14 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/11">XI</a></td>
#  <td><a href="/editions/11">1936</a></td>
#  <td><a href="/editions/11">Berlin</a></td>
#  <td><img src="/images/flags/GER.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 1 August</td>
#  <td>16 August</td>
#  <td>2 – 16 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/51">XII</a></td>
#  <td><a href="/editions/51">1940</a></td>
#  <td><a href="/editions/51">Helsinki</a></td>
#  <td><img src="/images/flags/FIN.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <
img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>19 July</td>
#  <td> 4 August</td>
#  <td>20 July –  4 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/25">XXVII</a></td>
#  <td><a href="/editions/25">2000</a></td>
#  <td><a href="/editions/25">Sydney</a></td>
#  <td><img src="/images/flags/AUS.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>15 September</td>
#  <td> 1 October</td>
#  <td>13 September –  1 October</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/26">XXVIII</a></td>
#  <td><a href="/editions/26">2004</a></td>
#  <td><a href="/editions/26">Athina</a></td>
#  <td><img src="/images/flags/GRE.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>13 August</td>
#  <td>29 August</td>
#  <td>11 – 29 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/53">XXIX</a></td>
#  <td><a href="/editions/53">2008</a></td>
#  <td><a href="/editions/53">Beijing</a></td>
#  <td><img src="/images/flags/CHN.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 8 August</td>
#  <td>24 August</td>
#  <td>6 – 24 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/54">XXX</a></td>
#  <td><a href="/editions/54">2012</a></td>
#  <td><a href="/editions/54">London</a></td>
#  <td><img src="/images/flags/GBR.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>27 July</td>
#  <td>12 August</td>
#  <td>25 July – 12 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/59">XXXI</a></td>
#  <td><a href="/editions/59">2016</a></td>
#  <td><a href="/editions/59">Rio de Janeiro</a></td>
#  <td><img src="/images/flags/BRA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td> 5 August</td>
#  <td>21 August</td>
#  <td>3 – 21 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/61">XXXII</a></td>
#  <td><a href="/editions/61">2020</a></td>
#  <td><a href="/editions/61">Tokyo</a></td>
#  <td><img src="/images/flags/JPN.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td>23 July</td>
#  <td> 8 August</td>
#  <td>21 July –  8 August</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/63">XXXIII</a></td>
#  <td><a href="/editions/63">2024</a></td>
#  <td><a href="/editions/63">Paris</a></td>
#  <td><img src="/images/flags/FRA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td></td>
#  <td></td>
#  <td>—</td>
#  <td>
#  </td>
#  </tr>,
#  <tr>
#  <td><a href="/editions/64">XXXIV</a></td>
#  <td><a href="/editions/64">2028</a></td>
#  <td><a href="/editions/64">Los Angeles</a></td>
#  <td><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/></td>
#  <td></td>
#  <td></td>
#  <td>—</td>
#  <td>
#  </td>
#  </tr>]

# %%
# loop through rows and get the image source tags


# define empty list to hold the src tags
flag_images = []

# set row number to pass to table_body[]
for row_num in range(len(body_rows)):

    # loop through each row in the table body and find all rows
    for row in table_body[row_num].find_all('td'):
         
        # check to see if the row has an img tag 
        if row.img:
            # append the img src tag to a list
            flag_images.append(row.img['src'])

# %%
# use regex to get the country code from the img src
import re
country_codes = []
# loop through list and pull 3 alphanumeric before '.'
for src in flag_images:
    code = re.findall(r"(\w{3})\.", src) # maybe not the most efficient way but all the strings were the same so took a shot at it
    # append to list
    country_codes.append(code)

# %%
# regex loop returned a list of lists so extract into single list
country_codes = [x[0] for x in country_codes]

# %%
# get rid of columns we don't need
sum_olympic_cln = sum_olympic_org[['Year', 'City', 'Country']].copy()
sum_olympic_cln.head()
# Out:
#    Year       City  Country
# 0  1896     Athina      NaN
# 1  1900      Paris      NaN
# 2  1904  St. Louis      NaN
# 3  1908     London      NaN
# 4  1912  Stockholm      NaN

# %%
# replace the NaNs in the Country column with country_codes list
sum_olympic_cln['Country'] = country_codes
sum_olympic_cln.head()
# Out:
#    Year       City Country
# 0  1896     Athina     GRE
# 1  1900      Paris     FRA
# 2  1904  St. Louis     USA
# 3  1908     London     GBR
# 4  1912  Stockholm     SWE

# %%
# check DF
sum_olympic_cln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     34 non-null     int64
#  1   City     34 non-null     object
#  2   Country  34 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 944.0+ bytes

# %%
sum_olympic_org
# Out:
#          #  Year               City  Country        Opened        Closed  \
# 0        I  1896             Athina      NaN       6 April      15 April
# 1       II  1900              Paris      NaN           NaN           NaN
# 2      III  1904          St. Louis      NaN        14 May           NaN
# 3       IV  1908             London      NaN       13 July           NaN
# 4        V  1912          Stockholm      NaN        6 July       27 July
# 5       VI  1916             Berlin      NaN           NaN           NaN
# 6      VII  1920          Antwerpen      NaN     14 August     30 August
# 7     VIII  1924              Paris      NaN        5 July       27 July
# 8       IX  1928          Amsterdam      NaN       28 July     12 August
# 9        X  1932        Los Angeles      NaN       30 July     14 August
# 10      XI  1936             Berlin      NaN      1 August     16 August
# 11     XII  1940           Helsinki      NaN           NaN           NaN
# 12    XIII  1944             London      NaN           NaN           NaN
# 13     XIV  1948             London      NaN       29 July     14 August
# 14      XV  1952           Helsinki      NaN       19 July      3 August
# 15     XVI  1956          Melbourne      NaN   22 November    8 December
# 16    XVII  1960               Roma      NaN     25 August  11 September
# 17   XVIII  1964              Tokyo      NaN    10 October    24 October
# 18     XIX  1968  Ciudad de MÃ©xico      NaN    12 October    27 October
# 19      XX  1972           MÃ¼nchen      NaN     26 August  11 September
# 20     XXI  1976          MontrÃ©al      NaN       17 July      1 August
# 21    XXII  1980             Moskva      NaN       19 July      3 August
# 22   XXIII  1984        Los Angeles      NaN       28 July     12 August
# 23    XXIV  1988              Seoul      NaN  17 September     2 October
# 24     XXV  1992          Barcelona      NaN       25 July      9 August
# 25    XXVI  1996            Atlanta      NaN       19 July      4 August
# 26   XXVII  2000             Sydney      NaN  15 September     1 October
# 27  XXVIII  2004             Athina      NaN     13 August     29 August
# 28    XXIX  2008            Beijing      NaN      8 August     24 August
# 29     XXX  2012             London      NaN       27 July     12 August
# 30    XXXI  2016     Rio de Janeiro      NaN      5 August     21 August
# 31   XXXII  2020              Tokyo      NaN       23 July      8 August
# 32  XXXIII  2024              Paris      NaN           NaN           NaN
# 33   XXXIV  2028        Los Angeles      NaN           NaN           NaN
#
#                    Competition           Unnamed: 7
# 0               6 â 13 April                  NaN
# 1        14 May â 28 October                  NaN
# 2       1 July â 23 November                  NaN
# 3      27 April â 31 October                  NaN
# 4            5 May â 27 July                  NaN
# 5                          â  Not held due to war
# 6    23 April â 12 September                  NaN
# 7            4 May â 27 July                  NaN
# 8         17 May â 12 August                  NaN
# 9        30 July â 14 August                  NaN
# 10             2 â 16 August                  NaN
# 11                         â  Not held due to war
# 12                         â  Not held due to war
# 13       26 July â 14 August                  NaN
# 14        14 July â 3 August                  NaN
# 15  22 November â 8 December                  NaN
# 16  25 August â 11 September                  NaN
# 17           11 â 24 October                  NaN
# 18           12 â 27 October                  NaN
# 19  26 August â 11 September                  NaN
# 20        18 July â 1 August                  NaN
# 21        20 July â 3 August                  NaN
# 22        6 July â 12 August                  NaN
# 23  17 September â 2 October                  NaN
# 24        24 July â 9 August                  NaN
# 25        20 July â 4 August                  NaN
# 26  13 September â 1 October                  NaN
# 27            11 â 29 August                  NaN
# 28             6 â 24 August                  NaN
# 29       25 July â 12 August                  NaN
# 30             3 â 21 August                  NaN
# 31        21 July â 8 August                  NaN
# 32                         â                  NaN
# 33                         â                  NaN

# %%
# get rid of everything before 1964 and after 2016
analysis_years = sum_olympic_cln.copy()
analysis_years.drop(analysis_years[(analysis_years['Year'] < 1964) | (analysis_years['Year'] > 2016)].index, inplace=True)

# %%
analysis_years.rename(columns={"City": "Host_City", "Country":"Host_Country"}, inplace=True)
# analysis_years.head()

# %%
# send years with host cities and countries to csv
# analysis_years.to_csv("host_cities.csv")

# %%
# merge the dataframes - doing this after becuase I didn't want to re-run the scrape.

# load host cities as DF
# host_cities_df = pd.read_csv("host_cities.csv", index_col=0)

# %%
# load medals scrape csv as DF
# all_country_medals_df = pd.read_csv("complete_year_datascrape_07182021.csv", index_col=0)

# %%
# merge the dataframes on year
# combined_data = all_country_medals_df.merge(right=host_cities_df, how="left", on="Year")
# combined_data.head()

# %%
# send merged dataframe to .csv
# combined_data.to_csv("medal_data_by_year.csv")

# %% [markdown]
# # Moving to individual year medals pages
# 1 - navigate to correct page
#
# 2 - locate medal table
#
# 3 - load medal table as DF with index as the year
#
# 4 - merge with the summer olympic table -

# %%
# get years into a list so you can use them for href and click
years_list = analysis_years['Year'].tolist()

# years are int - need them to be string to pass to scraping loop so convert
years_list = [str(x) for x in years_list]

# %%
years_list

# %%
# from xpath we know the table row to start is 18 
# browser.find_by_xpath('/html/body/div[2]/table[1]/tbody/tr[18]/td[2]/a'). click() # this also works but is less understandable

# NOTE: according to this link https://stackoverflow.com/questions/13784192/creating-an-empty-pandas-dataframe-then-filling-it it is not a good idea to append dataframes in a loop. Working on scraping to lists or dictionaries and then turning into dataframe but this loop should work despite it being memory intensive if we need to use it. 

# create the first dataframe - 1964
# complete_medals_table = Data - was going to create a blank dataframe to append to but apparently that's not a good idea

# test list = successful for 2 years
test_years = ['1964', '1968']

# set iterator
# counter = 0

# df dictionary - testing
# https://stackoverflow.com/questions/30233982/merge-dataframes-in-a-dictionary

all_years = {}

# start for loop to get all of the year medal tables
for year in test_years: # change back to years_list when testing complete

    browser.find_by_text(year).click() # this works - loop step 1

    # get page url - loop step 2
    page_url = browser.url

    # reset soup
    # parse HTML
    html = browser.html
    html_soup = soup(html, 'html.parser')

    # get all tables on the page as DFs 
    #page_dfs = pd.read_html(page_url)
    # print(f'Total tables: {len(page_dfs)}') # check number of tables on page - use for debugging

    # get the medal table and load to DF
    # medals_table = pd.read_html(page_url, match="NOC")[0] # loop step 3
    #all_years[year] = pd.read_html(page_url, match="NOC")[0] # loop step 3

    # add column 'year' with the year of the games - loop step 4
    # medals_table['Year'] = int(year)
    all_years[year]['Year'] = int(year)

    # rename the columns - loop step 5
    # medals_table.rename(columns={'NOC': 'Country', 'NOC.1': 'Country Code'}, inplace=True)
    all_years[year].rename(columns={'NOC': 'Country', 'NOC.1': 'Country Code'}, inplace=True)

    # NOTE: may get rid of this in favor of adding to dictionary and then appending.
    # if this is the first year then just save as DF, otherwise append to the DF
    # if counter != 0:
        # medals_table = medals_table.append(medals_table, ignore_index=True)

    # counter += 1

    # go back to the main page
    browser.back()

browser.quit()

# %%
# ################# HH Test

##Extract Disciplines List
url = "https://www.olympedia.org/editions/16"
browser.visit(url)

# parse HTML
html = browser.html
html_soup = soup(html, 'html.parser')
#test_disc_df = pd.read_html(url)
table_disciplines = pd.read_html(url)
other_disciplines = pd.read_html(url)
# len(table_tokyo) # returns 1 so that is the table that we want
#table_disciplines
#other_disciplines

# %%
pd.read_html(url)[3]
# Out:
#                      0                    1              2
# 0  Artistic Gymnastics  Equestrian Dressage         Rowing
# 1            Athletics  Equestrian Eventing        Sailing
# 2           Basketball   Equestrian Jumping       Shooting
# 3               Boxing              Fencing       Swimming
# 4         Canoe Sprint             Football     Volleyball
# 5         Cycling Road               Hockey     Water Polo
# 6        Cycling Track                 Judo  Weightlifting
# 7               Diving    Modern Pentathlon      Wrestling

# %%
#Gather List of Main Disciplines
df_table_disciplines = pd.read_html(url)[3]
#df_table_disciplines

df_table0 = df_table_disciplines[0]
df_table1 = df_table_disciplines[1]
df_table2 = df_table_disciplines[2]

pieces = {"1": df_table0,"2": df_table1,"3": df_table2}
df_table_disciplines = pd.concat(pieces)

main_disciplines = df_table_disciplines.tolist()

# %%
main_disciplines
# Out:
# ['Artistic Gymnastics',
#  'Athletics',
#  'Basketball',
#  'Boxing',
#  'Canoe Sprint',
#  'Cycling Road',
#  'Cycling Track',
#  'Diving',
#  'Equestrian Dressage',
#  'Equestrian Eventing',
#  'Equestrian Jumping',
#  'Fencing',
#  'Football',
#  'Hockey',
#  'Judo',
#  'Modern Pentathlon',
#  'Rowing',
#  'Sailing',
#  'Shooting',
#  'Swimming',
#  'Volleyball',
#  'Water Polo',
#  'Weightlifting',
#  'Wrestling']

# %%
#Gather list of Other Disciplines
df_other_disc = pd.read_html(url)[4]


df_table0 = df_other_disc[0]
df_table1 = df_other_disc[1]
df_table2 = df_other_disc[2]

pieces = {"1": df_table0,"2": df_table1,"3": df_table2}
df_other_disc = pd.concat(pieces)
    
other_disciplines = df_other_disc.tolist()
other_disciplines
# Out:
# ['Baseball', 'Kendo', 'Kyudo', 'Sumo', nan, nan]

# %%
discipline_combo = main_disciplines + other_disciplines
df_disciplines_all = pd.DataFrame(discipline_combo)
df_disciplines_all.dropna()
# Out:
#                       0
# 0   Artistic Gymnastics
# 1             Athletics
# 2            Basketball
# 3                Boxing
# 4          Canoe Sprint
# 5          Cycling Road
# 6         Cycling Track
# 7                Diving
# 8   Equestrian Dressage
# 9   Equestrian Eventing
# 10   Equestrian Jumping
# 11              Fencing
# 12             Football
# 13               Hockey
# 14                 Judo
# 15    Modern Pentathlon
# 16               Rowing
# 17              Sailing
# 18             Shooting
# 19             Swimming
# 20           Volleyball
# 21           Water Polo
# 22        Weightlifting
# 23            Wrestling
# 24             Baseball
# 25                Kendo
# 26                Kyudo
# 27                 Sumo

# %%
######### HH Single Competition Extract

# %%
#Find the right competition
url = "https://www.olympedia.org/editions/16"
browser.visit(url)

competition = df_disciplines_all[0][1]
print("going to...   " + competition)

browser.find_by_text(competition).click() # this works - loop step 1

# get page url
page_url = browser.url

# reset soup
# parse HTML
html = browser.html
html_soup = soup(html, 'html.parser')
# Out:
# going to...   Athletics

# %%
html_soup
# Out:
# <html><head>
# <title>Olympedia – 1964 Summer Olympics Overview</title>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="sXmMJUtCyI++ngoOPwK07h+2RLsIOYhyAMe4ObX9QxIcgXEahhk48OBxXF+QQPr7ItKeEMtmS9VzmkIaezMbYg==" name="csrf-token"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="EN" http-equiv="content-language"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/assets/bootstrap.min-460a43de22fd9534d595e5aea2715cb154560291c9c6401b526e31c86a5ce32d.css" media="all" rel="stylesheet"/>
# <link href="/assets/bootstrap-sortable-363d232309d54b549fa85446295ef2b5d290e3f8a49f1a646247340be3705ef9.css" media="all" rel="stylesheet"/>
# <link href="/assets/jquery-ui-1.11.4.min-359ba1b9eb679ad05fb4c8fda710ee4c0239354f1ba635200b6065638295d646.css" media="all" rel="stylesheet"/>
# <link href="/assets/lightbox-e29689e123fc27505d2b9d919f43ffcb6fade539cb4670f21c35aa07848105e7.css" media="screen" rel="stylesheet"/>
# <link data-turbolinks-track="true" href="/assets/application-dabe0afec76f540b074f0f63c688a540786e3cc47508864701ac4bfcd2198724.css" media="all" rel="stylesheet"/>
# <link href="https://cdn.jsdelivr.net/gh/openlayers/openlayers.github.io@master/en/v6.4.3/css/ol.css" media="screen" rel="stylesheet"/>
# <script data-turbolinks-track="true" src="/assets/application-e1a1e4d6a20243befcce18acb216d9b0e6082405323ce1f5dfbf47c401111aa1.js"></script>
# <script src="/assets/jquery-1.11.2.min-cc83565074b3fa7f2283f7f4d56b90ad171ede87008448ed5d2e91c50575bed1.js"></script>
# <script src="/assets/jquery-ui-1.11.4.min-1f37fd37d8db0404488ac8f6505560e48d1364ef1c81e384ac695e143049ab0f.js"></script>
# <script src="/assets/bootstrap.min-81d6fe3a991358b79b083d075ca476712c9f11c5c890047486176bde863c499e.js"></script>
# <script src="/assets/moment-ded3cbd5de5ae075c44be4149abb630c658e8789f17ccfb162e6bb7664e8bec9.js"></script>
# <script src="/assets/bootstrap-sortable-cd614fbc8d2030bc050ce63652169ed36d970209a94062fa218c631f2c04dc9f.js"></script>
# <script src="https://cdn.jsdelivr.net/gh/openlayers/openlayers.github.io@master/en/v6.4.3/build/ol.js"></script>
# </head>
# <body>
# <div class="navbar navbar-default navbar-fixed-top" role="navigation">
# <div class="navbar-header">
# <div class="button navbar-toggle" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar">
# <span class="icon-bar">
# <span class="icon-bar"></span>
# </span>
# </span>
# </div>
# <a class="navbar-brand" href="/">Olympedia</a>
# </div>
# <div class="collapse navbar-collapse navbar-ex1-collapse">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# Athletes
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/athletes/advanced_search">Advanced search</a></li>
# <li><a href="/horses">Horse search</a></li>
# <li><a href="/family_relations">Related Olympians</a></li>
# <li><a href="/counts">Counts</a></li>
# <li><a href="/athletes/doubles">Doubles</a></li>
# <li><a href="/athletes/lists">Lists</a></li>
# <li class="divider"></li>
# <li><a href="/athletes">Athletes</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# Countries
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/countries/head_to_head">Head-to-head</a></li>
# <li><a href="/countries/best_results">Best results</a></li>
# <li><a href="/countries/comparison">Results comparison</a></li>
# <li class="divider"></li>
# <li><a href="/countries">Countries</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# Games
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/editions">Games</a></li>
# <li><a href="/editions/medals">Medals</a></li>
# <li><a href="/editions/results">Results</a></li>
# <li><a href="/ceremonies">Opening ceremony</a></li>
# <li><a href="/venues/menu">Venues</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# Sports
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/sports">Disciplines &amp; Sports</a></li>
# <li></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# IOC
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/organizations">Organizations</a></li>
# <li><a href="/definitions">Definitions</a></li>
# <li><a href="/meetings">Meetings</a></li>
# <li><a href="/ioc/host_cities">Host city selection</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# Statistics
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu">
# <li></li>
# <li><a href="/statistics/medal/country">Medals by country</a></li>
# <li><a href="/statistics/medal/athlete">Medals by athlete</a></li>
# <li><a href="/statistics/medal_table">Medal tables</a></li>
# <li><a href="/statistics/participation">Participations</a></li>
# <li><a href="/records">Records</a></li>
# <li><a href="/statistics/age">Age records</a></li>
# <li><a href="/lists">Lists</a></li>
# <li><a href="/today">Today</a></li>
# <li></li>
# <li class="divider"></li>
# <li><a href="/statistics">Statistics</a></li>
# </ul>
# </li>
# <li><a href="/feedbacks/new">Feedback</a></li>
# <form accept-charset="UTF-8" action="/athletes/quick_search" class="navbar-form navbar-left" method="post" role="search"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="sXmMJUtCyI++ngoOPwK07h+2RLsIOYhyAMe4ObX9QxIcgXEahhk48OBxXF+QQPr7ItKeEMtmS9VzmkIaezMbYg=="/>
# <div class="form-group">
# <input class="form-control" id="query" name="query" placeholder="Athlete search" type="text"/>
# </div>
# <input class="btn btn-default" data-disable-with="Go" name="commit" type="submit" value="Go"/>
# </form>
# </ul>
# </div>
# </div>
# <div class="container">
# <ol class="breadcrumb">
# <li>
# <a href="/">Home</a>
# </li>
# <li><a href="/editions">Games</a></li><li class="active">1964 Summer Olympics Overview</li>
# </ol>
# <h1>1964 Summer Olympics</h1>
# <h2>Facts</h2>
# <table class="biotable">
# <tbody><tr>
# <th>Competition type</th>
# <td>Olympic Games</td>
# </tr>
# <tr>
# <th>Number and Year</th>
# <td>XVIII / 1964</td>
# </tr>
# <tr>
# <th>Host city</th>
# <td>
# Tokyo, Japan
# (<a href="/venues/editions/16">Venues</a>)
# </td>
# </tr>
# <tr>
# <th>Opening ceremony</th>
# <td>
# 10 October
# </td>
# </tr>
# <tr>
# <th>Closing ceremony</th>
# <td>
# 24 October
# </td>
# </tr>
# <tr>
# <th>Competition dates</th>
# <td>
# 11 – 24 October
# </td>
# </tr>
# <tr>
a></td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# </tr>
# <tr class="top">
# <td><a href="/athletes/78203">Henry Carr</a></td>
# <td><a href="/countries/USA"><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/> USA</a></td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# </tr>
# <tr class="top">
# <td><a href="/athletes/78533">Bob Hayes</a></td>
# <td><a href="/countries/USA"><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/> USA</a></td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# </tr>
# <tr class="top">
# <td><a href="/athletes/78678">Mike Larrabee</a></td>
# <td><a href="/countries/USA"><img src="/images/flags/USA.png" style="padding-right: 2px; vertical-align: middle"/> USA</a></td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# </tr>
# </tbody></table>
# <p>
# <i><a href="/editions/16/medal">All medalists at these Games</a></i>
# </p>
# </div>
# <footer class="footer">
# <br/>
# <div class="panel panel-info">
# <div class="panel-heading">
# <h3 class="panel-title">
# <span class="glyphicon glyphicon-info-sign"></span>
# Did you know?
# </h3>
# </div>
# <div class="panel-body">
# <p>The wrestling events at the 1960 Olympics in Rome were held in the Basilica of Maxentius, which was completed in 312 AD.</p>
# </div>
# </div>
# <div class="container">
# <p>
# <a href="/users/sign_in">Login</a>
# |
# <a href="/statistics/olympedia">Statistics</a>
# |
# <a href="/static/about">About</a>
# |
# <a href="/static/faq">FAQ</a>
# |
# <a href="/feedbacks/new">Feedback</a>
# </p>
# <p>
# © <a href="/static/about">OlyMADMen</a> 2006 — 2021
# </p>
# </div>
# </footer>
# <script src="/assets/lightbox.min-40fdcc195c5982250c8901f2c160e15342941a311faf6372c04117c0d9c44bc7.js"></script>
# <script>
#   $('.footnote').tooltip();
# </script>
# <div class="lightboxOverlay" id="lightboxOverlay" style="display: none;"></div><div class="lightbox" id="lightbox" style="display: none;"><div class="lb-outerContainer"><div class="lb-container"><img class="lb-image" src=""/><div class="lb-nav"><a class="lb-prev" href=""></a><a class="lb-next" href=""></a></div><div class="lb-loader"><a class="lb-cancel"></a></div></div></div><div class="lb-dataContainer"><div class="lb-data"><div class="lb-details"><span class="lb-caption"></span><span class="lb-number"></span></div><div class="lb-closeContainer"><a class="lb-close"></a></div></div></div></div></body></html>

# %%
page_dfs = pd.read_html(page_url)
page_dfs
# Out:
# [              0                       1
#  0         Dates  14 â 21 October 1964
#  1  Medal Events                      36,
#                               Event   Status                    Date  \
#  0                  100 metres, Men  Olympic  14 â 15 October 1964
#  1                  200 metres, Men  Olympic  16 â 17 October 1964
#  2                  400 metres, Men  Olympic  17 â 19 October 1964
#  3                  800 metres, Men  Olympic  14 â 16 October 1964
#  4                1,500 metres, Men  Olympic  17 â 21 October 1964
#  5                5,000 metres, Men  Olympic  16 â 18 October 1964
#  6               10,000 metres, Men  Olympic         14 October 1964
#  7                    Marathon, Men  Olympic         21 October 1964
#  8          110 metres Hurdles, Men  Olympic  17 â 18 October 1964
#  9          400 metres Hurdles, Men  Olympic  14 â 16 October 1964
#  10  3,000 metres Steeplechase, Men  Olympic  15 â 17 October 1964
#  11       4 x 100 metres Relay, Men  Olympic  20 â 21 October 1964
#  12       4 x 400 metres Relay, Men  Olympic  20 â 21 October 1964
#  13         20 kilometres Walk, Men  Olympic         15 October 1964
#  14         50 kilometres Walk, Men  Olympic         18 October 1964
#  15                  High Jump, Men  Olympic  20 â 21 October 1964
#  16                 Pole Vault, Men  Olympic  15 â 17 October 1964
#  17                  Long Jump, Men  Olympic         18 October 1964
#  18                Triple Jump, Men  Olympic         16 October 1964
#  19                   Shot Put, Men  Olympic         17 October 1964
#  28        80 metres Hurdles, Women     Karin Balzer    GER
#  29    4 Ã 100 metres Relay, Women           Poland    POL
#  30                High Jump, Women   Iolanda BalaÈ    ROU
#  31                Long Jump, Women        Mary Rand    GBR
#  32                 Shot Put, Women     Tamara Press    URS
#  33             Discus Throw, Women     Tamara Press    URS
#  34            Javelin Throw, Women   Mihaela PeneÈ    ROU
#  35               Pentathlon, Women      Irina Press    URS
#
#                         Silver Silver.1                Bronze Bronze.1
#  0           Enrique Figuerola      CUB          Harry Jerome      CAN
#  1                Paul Drayton      USA         Edwin Roberts      TTO
#  2             Wendell Mottley      TTO     Andrzej BadeÅski      POL
#  3               Bill Crothers      CAN       Wilson Kiprugut      KEN
#  4              Josef OdloÅ¾il      TCH           John Davies      NZL
#  5              Harald Norpoth      GER        Bill Dellinger      USA
#  6            Mohamad Gammoudi      TUN            Ron Clarke      AUS
#  7               Basil Heatley      GBR     Kokichi Tsuburaya      JPN
#  8             Blaine Lindgren      USA     Anatoly Mikhaylov      URS
#  9                 John Cooper      GBR      Salvatore Morale      ITA
#  10           Maurice Herriott      GBR         Ivan Belyayev      URS
#  11                     Poland      POL                France      FRA
#  12              Great Britain      GBR   Trinidad and Tobago      TTO
#  13             Dieter Lindner      GER   Vladimir Golubnichy      URS
#  14                Paul Nihill      GBR     Ingvar Pettersson      SWE
#  15                John Thomas      USA            John Rambo      USA
#  16         Wolfgang Reinhardt      GER        Klaus Lehnertz      GER
#  17               Ralph Boston      USA    Igor Ter-Ovanesyan      URS
#  18             Oleg Fedoseyev      URS     Viktor Kravchenko      URS
#  19               Randy Matson      USA         Vilmos VarjÃº      HUN
#  20             LudvÃ­k DanÄk      TCH            Dave Weill      USA
#  21           Gyula ZsivÃ³tzky      HUN             Uwe Beyer      GER
#  22           Gergely KulcsÃ¡r      HUN         JÄnis LÅ«sis      URS
#  23                   Rein Aun      URS    Hans-Joachim Walde      GER
#  24              Edith McGuire      USA      Ewa KÅobukowska      POL
#  25         Irena Kirszenstein      POL         Marilyn Black      AUS
#  26                 Ann Packer      GBR           Judy Amoore      AUS
#  27         Maryvonne Dupureur      FRA    Marise Chamberlain      NZL
#  28             Teresa CiepÅy      POL           Pam Kilborn      AUS
#  29              United States      USA         Great Britain      GBR
#  30        Michele Mason-Brown      AUS      Taisiya Chenchik      URS
#  31         Irena Kirszenstein      POL  Tatyana Shchelkanova      URS
#  32  Renate Garisch-Culmberger      GER         Galina Zybina      URS
#  33                Ingrid Lotz      GER           Lia Manoliu      ROU
#  34         MÃ¡rta Antal-Rudas      HUN     Yelena Gorchakova      URS
#  35                  Mary Rand      GBR       Galina Bystrova      URS  ,
#                      NOC NOC.1  Gold  Silver  Bronze  Total
#  0         United States   USA    14       7       3     24
#  1          Soviet Union   URS     5       2      11     18
#  2         Great Britain   GBR     4       7       1     12
#  3               Germany   GER     2       5       3     10
#  4                Poland   POL     2       4       2      8
#  5           New Zealand   NZL     2       0       2      4
#  6               Romania   ROU     2       0       1      3
#  7             Australia   AUS     1       1       4      6
#  8                 Italy   ITA     1       0       1      2
#  9               Belgium   BEL     1       0       0      1
#  10             Ethiopia   ETH     1       0       0      1
#  11              Finland   FIN     1       0       0      1
#  12              Hungary   HUN     0       3       1      4
#  13       Czechoslovakia   TCH     0       2       0      2
#  14  Trinidad and Tobago   TTO     0       1       2      3
#  15               Canada   CAN     0       1       1      2
#  16               France   FRA     0       1       1      2
#  17                 Cuba   CUB     0       1       0      1
#  18              Tunisia   TUN     0       1       0      1
#  19                Japan   JPN     0       0       1      1
#  20                Kenya   KEN     0       0       1      1
#  21               Sweden   SWE     0       0       1      1]

# %%
# Gather Results Table
df_results = pd.read_html(page_url)[2]
df_results
# Out:
#                              Event             Gold Gold.1  \
# 0                  100 metres, Men        Bob Hayes    USA
# 1                  200 metres, Men       Henry Carr    USA
# 2                  400 metres, Men    Mike Larrabee    USA
# 3                  800 metres, Men      Peter Snell    NZL
# 4                1,500 metres, Men      Peter Snell    NZL
# 5                5,000 metres, Men        Bob Schul    USA
# 6               10,000 metres, Men      Billy Mills    USA
# 7                    Marathon, Men     Abebe Bikila    ETH
# 8          110 metres Hurdles, Men      Hayes Jones    USA
# 9          400 metres Hurdles, Men       Rex Cawley    USA
# 10  3,000 metres Steeplechase, Men  Gaston Roelants    BEL
# 11      4 Ã 100 metres Relay, Men    United States    USA
# 12      4 Ã 400 metres Relay, Men    United States    USA
# 13         20 kilometres Walk, Men     Ken Matthews    GBR
# 14         50 kilometres Walk, Men     Abdon Pamich    ITA
# 15                  High Jump, Men    Valery Brumel    URS
# 16                 Pole Vault, Men      Fred Hansen    USA
# 17                  Long Jump, Men      Lynn Davies    GBR
# 18                Triple Jump, Men    JÃ³zef Szmidt    POL
# 19                   Shot Put, Men      Dallas Long    USA
# 20               Discus Throw, Men        Al Oerter    USA
# 21               Hammer Throw, Men     Romuald Klim    URS
# 22              Javelin Throw, Men     Pauli Nevala    FIN
# 23                  Decathlon, Men    Willi Holdorf    GER
# 24               100 metres, Women      Wyomia Tyus    USA
# 25               200 metres, Women    Edith McGuire    USA
# 26               400 metres, Women   Betty Cuthbert    AUS
# 27               800 metres, Women       Ann Packer    GBR
# 28        80 metres Hurdles, Women     Karin Balzer    GER
# 29    4 Ã 100 metres Relay, Women           Poland    POL
# 30                High Jump, Women   Iolanda BalaÈ    ROU
# 31                Long Jump, Women        Mary Rand    GBR
# 32                 Shot Put, Women     Tamara Press    URS
# 33             Discus Throw, Women     Tamara Press    URS
# 34            Javelin Throw, Women   Mihaela PeneÈ    ROU
# 35               Pentathlon, Women      Irina Press    URS
#
#                        Silver Silver.1                Bronze Bronze.1
# 0           Enrique Figuerola      CUB          Harry Jerome      CAN
# 1                Paul Drayton      USA         Edwin Roberts      TTO
# 2             Wendell Mottley      TTO     Andrzej BadeÅski      POL
# 3               Bill Crothers      CAN       Wilson Kiprugut      KEN
# 4              Josef OdloÅ¾il      TCH           John Davies      NZL
# 5              Harald Norpoth      GER        Bill Dellinger      USA
# 6            Mohamad Gammoudi      TUN            Ron Clarke      AUS
# 7               Basil Heatley      GBR     Kokichi Tsuburaya      JPN
# 8             Blaine Lindgren      USA     Anatoly Mikhaylov      URS
# 9                 John Cooper      GBR      Salvatore Morale      ITA
# 10           Maurice Herriott      GBR         Ivan Belyayev      URS
# 11                     Poland      POL                France      FRA
# 12              Great Britain      GBR   Trinidad and Tobago      TTO
# 13             Dieter Lindner      GER   Vladimir Golubnichy      URS
# 14                Paul Nihill      GBR     Ingvar Pettersson      SWE
# 15                John Thomas      USA            John Rambo      USA
# 16         Wolfgang Reinhardt      GER        Klaus Lehnertz      GER
# 17               Ralph Boston      USA    Igor Ter-Ovanesyan      URS
# 18             Oleg Fedoseyev      URS     Viktor Kravchenko      URS
# 19               Randy Matson      USA         Vilmos VarjÃº      HUN
# 20             LudvÃ­k DanÄk      TCH            Dave Weill      USA
# 21           Gyula ZsivÃ³tzky      HUN             Uwe Beyer      GER
# 22           Gergely KulcsÃ¡r      HUN         JÄnis LÅ«sis      URS
# 23                   Rein Aun      URS    Hans-Joachim Walde      GER
# 24              Edith McGuire      USA      Ewa KÅobukowska      POL
# 25         Irena Kirszenstein      POL         Marilyn Black      AUS
# 26                 Ann Packer      GBR           Judy Amoore      AUS
# 27         Maryvonne Dupureur      FRA    Marise Chamberlain      NZL
# 28             Teresa CiepÅy      POL           Pam Kilborn      AUS
# 29              United States      USA         Great Britain      GBR
# 30        Michele Mason-Brown      AUS      Taisiya Chenchik      URS
# 31         Irena Kirszenstein      POL  Tatyana Shchelkanova      URS
# 32  Renate Garisch-Culmberger      GER         Galina Zybina      URS
# 33                Ingrid Lotz      GER           Lia Manoliu      ROU
# 34         MÃ¡rta Antal-Rudas      HUN     Yelena Gorchakova      URS
# 35                  Mary Rand      GBR       Galina Bystrova      URS

# %%
# Clean/Resolve Ties

#df_results_tiebreaker

# %%
# Find Location, Long, Lat

#for event in df_results['Event']:
event = df_results['Event'][1]
# Navigate to Event Details
print("going to...   " + event)
browser.find_by_text(event).click() # this works - loop step 1
# get page url
page_url = browser.url
# reset soup
# parse HTML
html = browser.html
html_soup = soup(html, 'html.parser')
# Out:
# going to...   Team All-Around, Men

# %%
df_event_details = pd.read_html(page_url)[0]
df_event_details
# Out:
#               0                       1
# 0         Dates  14 â 21 October 1964
# 1  Medal Events                      36

# %%
# Add Year, Discipline to Results Table
df_results['Year'] = '1964'

# %%
df_results
# Out:
#                              Event             Gold Gold.1  \
# 0                  100 metres, Men        Bob Hayes    USA
# 1                  200 metres, Men       Henry Carr    USA
# 2                  400 metres, Men    Mike Larrabee    USA
# 3                  800 metres, Men      Peter Snell    NZL
# 4                1,500 metres, Men      Peter Snell    NZL
# 5                5,000 metres, Men        Bob Schul    USA
# 6               10,000 metres, Men      Billy Mills    USA
# 7                    Marathon, Men     Abebe Bikila    ETH
# 8          110 metres Hurdles, Men      Hayes Jones    USA
# 9          400 metres Hurdles, Men       Rex Cawley    USA
# 10  3,000 metres Steeplechase, Men  Gaston Roelants    BEL
# 11      4 Ã 100 metres Relay, Men    United States    USA
# 12      4 Ã 400 metres Relay, Men    United States    USA
# 13         20 kilometres Walk, Men     Ken Matthews    GBR
# 14         50 kilometres Walk, Men     Abdon Pamich    ITA
# 15                  High Jump, Men    Valery Brumel    URS
# 16                 Pole Vault, Men      Fred Hansen    USA
# 17                  Long Jump, Men      Lynn Davies    GBR
# 18                Triple Jump, Men    JÃ³zef Szmidt    POL
# 19                   Shot Put, Men      Dallas Long    USA
# 20               Discus Throw, Men        Al Oerter    USA
# 21               Hammer Throw, Men     Romuald Klim    URS
# 22              Javelin Throw, Men     Pauli Nevala    FIN
# 23                  Decathlon, Men    Willi Holdorf    GER
# 24               100 metres, Women      Wyomia Tyus    USA
# 25               200 metres, Women    Edith McGuire    USA
# 26               400 metres, Women   Betty Cuthbert    AUS
# 27               800 metres, Women       Ann Packer    GBR
# 28        80 metres Hurdles, Women     Karin Balzer    GER
# 29    4 Ã 100 metres Relay, Women           Poland    POL
# 30                High Jump, Women   Iolanda BalaÈ    ROU
# 31                Long Jump, Women        Mary Rand    GBR
# 32                 Shot Put, Women     Tamara Press    URS
# 33             Discus Throw, Women     Tamara Press    URS
# 34            Javelin Throw, Women   Mihaela PeneÈ    ROU
# 35               Pentathlon, Women      Irina Press    URS
#
#                        Silver Silver.1                Bronze Bronze.1  Year
# 0           Enrique Figuerola      CUB          Harry Jerome      CAN  1964
# 1                Paul Drayton      USA         Edwin Roberts      TTO  1964
# 2             Wendell Mottley      TTO     Andrzej BadeÅski      POL  1964
# 3               Bill Crothers      CAN       Wilson Kiprugut      KEN  1964
# 4              Josef OdloÅ¾il      TCH           John Davies      NZL  1964
# 5              Harald Norpoth      GER        Bill Dellinger      USA  1964
# 6            Mohamad Gammoudi      TUN            Ron Clarke      AUS  1964
# 7               Basil Heatley      GBR     Kokichi Tsuburaya      JPN  1964
# 8             Blaine Lindgren      USA     Anatoly Mikhaylov      URS  1964
# 9                 John Cooper      GBR      Salvatore Morale      ITA  1964
# 10           Maurice Herriott      GBR         Ivan Belyayev      URS  1964
# 11                     Poland      POL                France      FRA  1964
# 12              Great Britain      GBR   Trinidad and Tobago      TTO  1964
# 13             Dieter Lindner      GER   Vladimir Golubnichy      URS  1964
# 14                Paul Nihill      GBR     Ingvar Pettersson      SWE  1964
# 15                John Thomas      USA            John Rambo      USA  1964
# 16         Wolfgang Reinhardt      GER        Klaus Lehnertz      GER  1964
# 17               Ralph Boston      USA    Igor Ter-Ovanesyan      URS  1964
# 18             Oleg Fedoseyev      URS     Viktor Kravchenko      URS  1964
# 19               Randy Matson      USA         Vilmos VarjÃº      HUN  1964
# 20             LudvÃ­k DanÄk      TCH            Dave Weill      USA  1964
# 21           Gyula ZsivÃ³tzky      HUN             Uwe Beyer      GER  1964
# 22           Gergely KulcsÃ¡r      HUN         JÄnis LÅ«sis      URS  1964
# 23                   Rein Aun      URS    Hans-Joachim Walde      GER  1964
# 24              Edith McGuire      USA      Ewa KÅobukowska      POL  1964
# 25         Irena Kirszenstein      POL         Marilyn Black      AUS  1964
# 26                 Ann Packer      GBR           Judy Amoore      AUS  1964
# 27         Maryvonne Dupureur      FRA    Marise Chamberlain      NZL  1964
# 28             Teresa CiepÅy      POL           Pam Kilborn      AUS  1964
# 29              United States      USA         Great Britain      GBR  1964
# 30        Michele Mason-Brown      AUS      Taisiya Chenchik      URS  1964
# 31         Irena Kirszenstein      POL  Tatyana Shchelkanova      URS  1964
# 32  Renate Garisch-Culmberger      GER         Galina Zybina      URS  1964
# 33                Ingrid Lotz      GER           Lia Manoliu      ROU  1964
# 34         MÃ¡rta Antal-Rudas      HUN     Yelena Gorchakova      URS  1964
# 35                  Mary Rand      GBR       Galina Bystrova      URS  1964

# %%
# Scrape Location Details

location = df_event_details[1][2]
# Navigate to Location Details
print("going to...   " + location)
browser.find_by_text(location).click() # this works - loop step 1
# get page url
page_url = browser.url
# reset soup
# parse HTML
html = browser.html
html_soup = soup(html, 'html.parser')
browser.back()

# %%
# Merge Data into MasterCompetitionData
df_MasterCompetitionData = pd.DataFrame() #first run

# %%
df_MasterCompetitionData.append(df_results)
# Out:
#                              Event             Gold Gold.1  \
# 0                  100 metres, Men        Bob Hayes    USA
# 1                  200 metres, Men       Henry Carr    USA
# 2                  400 metres, Men    Mike Larrabee    USA
# 3                  800 metres, Men      Peter Snell    NZL
# 4                1,500 metres, Men      Peter Snell    NZL
# 5                5,000 metres, Men        Bob Schul    USA
# 6               10,000 metres, Men      Billy Mills    USA
# 7                    Marathon, Men     Abebe Bikila    ETH
# 8          110 metres Hurdles, Men      Hayes Jones    USA
# 9          400 metres Hurdles, Men       Rex Cawley    USA
# 10  3,000 metres Steeplechase, Men  Gaston Roelants    BEL
# 11      4 Ã 100 metres Relay, Men    United States    USA
# 12      4 Ã 400 metres Relay, Men    United States    USA
# 13         20 kilometres Walk, Men     Ken Matthews    GBR
# 14         50 kilometres Walk, Men     Abdon Pamich    ITA
# 15                  High Jump, Men    Valery Brumel    URS
# 16                 Pole Vault, Men      Fred Hansen    USA
# 17                  Long Jump, Men      Lynn Davies    GBR
# 18                Triple Jump, Men    JÃ³zef Szmidt    POL
# 19                   Shot Put, Men      Dallas Long    USA
# 20               Discus Throw, Men        Al Oerter    USA
# 21               Hammer Throw, Men     Romuald Klim    URS
# 22              Javelin Throw, Men     Pauli Nevala    FIN
# 23                  Decathlon, Men    Willi Holdorf    GER
# 24               100 metres, Women      Wyomia Tyus    USA
# 25               200 metres, Women    Edith McGuire    USA
# 26               400 metres, Women   Betty Cuthbert    AUS
# 27               800 metres, Women       Ann Packer    GBR
# 28        80 metres Hurdles, Women     Karin Balzer    GER
# 29    4 Ã 100 metres Relay, Women           Poland    POL
# 30                High Jump, Women   Iolanda BalaÈ    ROU
# 31                Long Jump, Women        Mary Rand    GBR
# 32                 Shot Put, Women     Tamara Press    URS
# 33             Discus Throw, Women     Tamara Press    URS
# 34            Javelin Throw, Women   Mihaela PeneÈ    ROU
# 35               Pentathlon, Women      Irina Press    URS
#
#                        Silver Silver.1                Bronze Bronze.1  Year
# 0           Enrique Figuerola      CUB          Harry Jerome      CAN  1964
# 1                Paul Drayton      USA         Edwin Roberts      TTO  1964
# 2             Wendell Mottley      TTO     Andrzej BadeÅski      POL  1964
# 3               Bill Crothers      CAN       Wilson Kiprugut      KEN  1964
# 4              Josef OdloÅ¾il      TCH           John Davies      NZL  1964
# 5              Harald Norpoth      GER        Bill Dellinger      USA  1964
# 6            Mohamad Gammoudi      TUN            Ron Clarke      AUS  1964
# 7               Basil Heatley      GBR     Kokichi Tsuburaya      JPN  1964
# 8             Blaine Lindgren      USA     Anatoly Mikhaylov      URS  1964
# 9                 John Cooper      GBR      Salvatore Morale      ITA  1964
# 10           Maurice Herriott      GBR         Ivan Belyayev      URS  1964
# 11                     Poland      POL                France      FRA  1964
# 12              Great Britain      GBR   Trinidad and Tobago      TTO  1964
# 13             Dieter Lindner      GER   Vladimir Golubnichy      URS  1964
# 14                Paul Nihill      GBR     Ingvar Pettersson      SWE  1964
# 15                John Thomas      USA            John Rambo      USA  1964
# 16         Wolfgang Reinhardt      GER        Klaus Lehnertz      GER  1964
# 17               Ralph Boston      USA    Igor Ter-Ovanesyan      URS  1964
# 18             Oleg Fedoseyev      URS     Viktor Kravchenko      URS  1964
# 19               Randy Matson      USA         Vilmos VarjÃº      HUN  1964
# 20             LudvÃ­k DanÄk      TCH            Dave Weill      USA  1964
# 21           Gyula ZsivÃ³tzky      HUN             Uwe Beyer      GER  1964
# 22           Gergely KulcsÃ¡r      HUN         JÄnis LÅ«sis      URS  1964
# 23                   Rein Aun      URS    Hans-Joachim Walde      GER  1964
# 24              Edith McGuire      USA      Ewa KÅobukowska      POL  1964
# 25         Irena Kirszenstein      POL         Marilyn Black      AUS  1964
# 26                 Ann Packer      GBR           Judy Amoore      AUS  1964
# 27         Maryvonne Dupureur      FRA    Marise Chamberlain      NZL  1964
# 28             Teresa CiepÅy      POL           Pam Kilborn      AUS  1964
# 29              United States      USA         Great Britain      GBR  1964
# 30        Michele Mason-Brown      AUS      Taisiya Chenchik      URS  1964
# 31         Irena Kirszenstein      POL  Tatyana Shchelkanova      URS  1964
# 32  Renate Garisch-Culmberger      GER         Galina Zybina      URS  1964
# 33                Ingrid Lotz      GER           Lia Manoliu      ROU  1964
# 34         MÃ¡rta Antal-Rudas      HUN     Yelena Gorchakova      URS  1964
# 35                  Mary Rand      GBR       Galina Bystrova      URS  1964

# %%
df_MasterCompetitionData
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Below is working on potentially parsing each table into a list and then making the dataframe from the list of lists.
#
# ### NOTE:
#
# It looks like the loop above is going to work and I doubt we are going to get graded on the time the code takes to process but left the link and maybe this challenge in here if we want to do it the 'most effective' way.
#
# Maybe this would be an issue if we had more data but it didn't seem like an issue for the medals by year.
#
# link with good info on why not to append dataframes but not related to scraping
# - https://stackoverflow.com/questions/13784192/creating-an-empty-pandas-dataframe-then-filling-it
#
# ## Ideas: Maybe pull tables with pd.read_html still and then send each column to a list with tolist(). Append those lists to a master list or dictionary, and then make a combined df with the data?

# %%
# started some testing on scraping to lists

# /html/body/div[2]/table[5]/thead/tr/th[1]
url = "https://www.olympedia.org/editions/16"

html = browser.html
html_soup = soup(html, 'html.parser')

# set table reference
year_results_table = html_soup.find_all('table')[5]
table_headers = []
for year_results_table
# get the table headers
# set the headers as dictionary keys
# append column values to the key:values
# go to the next page and repeat
# turn the dictionary into a dataframe
