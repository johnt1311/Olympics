# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
pip install plotly
# Out:
# ...
#   Using cached plotly-5.1.0-py2.py3-none-any.whl (20.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data_to_load = "MasterResultsData_Cleaned.csv"

# %%
data_df = pd.read_csv(data_to_load, encoding = "ISO-8859-1")

# %%
data_df
# Out:
#                                 Event                                 Name  \
# 0                 Balance Beam, Women           VÃÂra ÃÂÃÂ¡slavskÃÂ¡
# 1                 Balance Beam, Women                        Tamara Manina
# 2                 Balance Beam, Women                      Larisa Latynina
# 3                 Floor Exercise, Men                    Franco Menichelli
# 4                 Floor Exercise, Men                                  NaN
# ...                               ...                                  ...
# 11677  Welterweight, Greco-Roman, Men                                  NaN
# 11678  Welterweight, Greco-Roman, Men                    Migran Arutyunyan
# 11679  Welterweight, Greco-Roman, Men                                  NaN
# 11680  Welterweight, Greco-Roman, Men  Shmagi BolkvadzeRÃÂsul ÃÂunayev
# 11681  Welterweight, Greco-Roman, Men                                  NaN
#
#        NOC  Pos.  Year           Discipline
# ...

# %%
data_2 = data_df.drop(columns='Name')
data_2
# Out:
#                                 Event  NOC  Pos.  Year           Discipline
# 0                 Balance Beam, Women  TCH     1  1964  Artistic Gymnastics
# 1                 Balance Beam, Women  URS     2  1964  Artistic Gymnastics
# 2                 Balance Beam, Women  URS     3  1964  Artistic Gymnastics
# 3                 Floor Exercise, Men  ITA     1  1964  Artistic Gymnastics
# 4                 Floor Exercise, Men  NaN     1  1964  Artistic Gymnastics
# ...                               ...  ...   ...   ...                  ...
# 11677  Welterweight, Greco-Roman, Men  NaN     1  2016            Wrestling
# 11678  Welterweight, Greco-Roman, Men  ARM     2  2016            Wrestling
# 11679  Welterweight, Greco-Roman, Men  NaN     2  2016            Wrestling
# 11680  Welterweight, Greco-Roman, Men  GEO     3  2016            Wrestling
# 11681  Welterweight, Greco-Roman, Men  AZE     3  2016            Wrestling
#
# [11682 rows x 5 columns]

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11682 entries, 0 to 11681
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Event       11682 non-null  object
#  1   NOC         10750 non-null  object
#  2   Pos.        11682 non-null  int64
#  3   Year        11682 non-null  int64
#  4   Discipline  11682 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 456.5+ KB

# %%
data_2.isnull().values.any()
# Out:
# True

# %%
data_2.dropna(subset=['NOC'], inplace=True)

# %%
data_2
# Out:
#                                 Event  NOC  Pos.  Year           Discipline
# 0                 Balance Beam, Women  TCH     1  1964  Artistic Gymnastics
# 1                 Balance Beam, Women  URS     2  1964  Artistic Gymnastics
# 2                 Balance Beam, Women  URS     3  1964  Artistic Gymnastics
# 3                 Floor Exercise, Men  ITA     1  1964  Artistic Gymnastics
# 5                 Floor Exercise, Men  URS     2  1964  Artistic Gymnastics
# ...                               ...  ...   ...   ...                  ...
# 11675    Welterweight, Freestyle, Men  UZB     3  2016            Wrestling
# 11676  Welterweight, Greco-Roman, Men  SRB     1  2016            Wrestling
# 11678  Welterweight, Greco-Roman, Men  ARM     2  2016            Wrestling
# 11680  Welterweight, Greco-Roman, Men  GEO     3  2016            Wrestling
# 11681  Welterweight, Greco-Roman, Men  AZE     3  2016            Wrestling
#
# [10750 rows x 5 columns]

# %%
data_2.isnull().values.any()
# Out:
# False

# %%
data_2.to_csv(r'pandas_cleaned.csv', index = False)
